# %% [markdown]
# # Pandas Datastructures

# %%
import pandas as pd

# %%
dict_student_1 = {'Name':'Harry Potter','Branch':'ECE','Hobbies':'Football,Cricket'}
dict_student_2 = {'Name':'Ronald Weasley','Branch':'CSE','Hobbies':'Chess'}
dict_student_3 = {'Name':'Ronald Weasley','Branch':'ECE','Hobbies':'Reading'}
dict_students = {'student_1':dict_student_1,'student_2':dict_student_2,'student_3':dict_student_3}
# dict_student_4 = {'Name':,'Branch':,'Hobbies':}

# %%
for student in dict_students.keys():
    print(dict_students[student]['Hobbies'])
# Out:
# Football,Cricket
# Chess
# Reading

# %% [markdown]
# ## Dataframe

# %%
df_student = pd.DataFrame()
df_student['Name'] = ['Harry Potter','Ronald Weasley','Harmoine Grenger']
df_student['Branch'] = ['ECE','CSE','ECE']
df_student['Hobbies'] = ['Football,Cricket','Chess','Reading']

# %%
df_student
# Out:
#                Name Branch           Hobbies
# 0      Harry Potter    ECE  Football,Cricket
# 1    Ronald Weasley    CSE             Chess
# 2  Harmoine Grenger    ECE           Reading

# %% [markdown]
# ## Series

# %%
ser_1 = pd.Series(['Draco','Civil','Bowling,Horse Riding'],index = ['Name','Branch','Hobbies'])
ser_1
# Out:
# Name                      Draco
# Branch                    Civil
# Hobbies    Bowling,Horse Riding
# dtype: object

# %%
df_student = df_student.append(ser_1,ignore_index= True)

# %%
df_student
# Out:
#                Name Branch               Hobbies
# 0      Harry Potter    ECE      Football,Cricket
# 1    Ronald Weasley    CSE                 Chess
# 2  Harmoine Grenger    ECE               Reading
# 3             Draco  Civil  Bowling,Horse Riding

# %% [markdown]
# # Load DataSet

# %%
import pandas as pd

# %%
df_drinks = pd.read_csv('drinks.csv',sep = ',',index_col = 0)

df_mpg = pd.read_csv('mpg.csv',sep = ',',index_col = 0)

df_euro = pd.read_csv('Euro_2012_stats_TEAM.csv',sep = ',',index_col = 0)

df_occupation = pd.read_csv('occupation.csv',index_col = 'user_id')

df_tips = pd.read_csv('tips.csv',index_col = 0)

df_titanic = pd.read_csv('titanic.csv',index_col = 0)

df_sales = pd.read_csv('sales_data.csv',index_col = 0)

df_chipo = pd.read_csv('chipotle.tsv',sep = '\t',index_col=0)

df_books = pd.read_csv('books.csv')

df_cricket = pd.read_csv('cricket_result.csv')

df_football = pd.read_csv('football_player.csv',index_col = 0)

# %%
df = df_chipo

# %%
df.head(10)
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# 3                1                           Chicken Bowl
# 3                1                          Side of Chips
# 4                1                          Steak Burrito
# 4                1                       Steak Soft Tacos
# 5                1                          Steak Burrito
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3         [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 3                                                       NaN     $1.69
# 4         [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 4         [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 5         [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
df.tail(10)
# Out:
#           quantity            item_name  \
# order_id
# 1831             1        Carnitas Bowl
# 1831             1                Chips
# 1831             1        Bottled Water
# 1832             1   Chicken Soft Tacos
# 1832             1  Chips and Guacamole
# 1833             1        Steak Burrito
# 1833             1        Steak Burrito
# 1834             1   Chicken Salad Bowl
# 1834             1   Chicken Salad Bowl
# 1834             1   Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1831      [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 1831                                                    NaN     $2.15
# 1831                                                    NaN     $1.50
# 1832       [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 1832                                                    NaN     $4.45
# 1833      [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 1833      [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df.shape
# Out:
# (4622, 4)

# %%
df.columns
# Out:
# Index(['quantity', 'item_name', 'choice_description', 'item_price'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4622 entries, 1 to 1834
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   quantity            4622 non-null   int64
#  1   item_name           4622 non-null   object
#  2   choice_description  3376 non-null   object
#  3   item_price          4622 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 180.5+ KB

# %%
df.describe(include = 'all')
# Out:
#            quantity     item_name choice_description item_price
# count   4622.000000          4622               3376       4622
# unique          NaN            50               1043         78
# top             NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN           726                134        730
# mean       1.075725           NaN                NaN        NaN
# std        0.410186           NaN                NaN        NaN
# min        1.000000           NaN                NaN        NaN
# 25%        1.000000           NaN                NaN        NaN
# 50%        1.000000           NaN                NaN        NaN
# 75%        1.000000           NaN                NaN        NaN
# max       15.000000           NaN                NaN        NaN

# %%
df['choice_description'].value_counts()
# Out:
# [Diet Coke]                                                                                                                                      134
# [Coke]                                                                                                                                           123
# [Sprite]                                                                                                                                          77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                            42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                 40
#                                                                                                                                                 ...
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Black Beans, Rice, Cheese, Sour Cream, Lettuce]]                                                         1
# [[Fresh Tomato Salsa (Mild), Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Pinto Beans, Cheese, Sour Cream, Lettuce]]      1
# [Fresh Tomato (Mild), [Guacamole, Rice, Black Beans]]                                                                                              1
# [[Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Lettuce]]                                    1
# [Tomatillo Green Chili Salsa, [Rice, Fajita Vegetables, Black Beans, Guacamole]]                                                                   1
# Name: choice_description, Length: 1043, dtype: int64

# %%
df['item_name'].value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# Chips and Tomatillo Red Chili Salsa       48
# Chicken Crispy Tacos                      47
# Chips and Tomatillo Green Chili Salsa     43
# Carnitas Soft Tacos                       40
# Steak Crispy Tacos                        35
# Chips and Tomatillo-Green Chili Salsa     31
# Steak Salad Bowl                          29
# Nantucket Nectar                          27
# Barbacoa Soft Tacos                       25
# Chips and Roasted Chili Corn Salsa        22
# Izze                                      20
# Chips and Tomatillo-Red Chili Salsa       20
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Chicken Salad                              9
# Veggie Soft Tacos                          7
# Carnitas Crispy Tacos                      7
# Veggie Salad                               6
# Carnitas Salad Bowl                        6
# Burrito                                    6
# Steak Salad                                4
# Crispy Tacos                               2
# Salad                                      2
# Bowl                                       2
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Carnitas Salad                             1
# Name: item_name, dtype: int64

# %%
df['item_name'].nunique()
# Out:
# 50

# %%
df['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
#        'Burrito', 'Crispy Tacos', 'Carnitas Crispy Tacos', 'Steak Salad',
#        'Chips and Mild Fresh Tomato Salsa', 'Veggie Soft Tacos',
#        'Carnitas Salad Bowl', 'Barbacoa Salad Bowl', 'Salad',
#        'Veggie Crispy Tacos', 'Veggie Salad', 'Carnitas Salad'],
#       dtype=object)

# %%
df.index
# Out:
# Int64Index([   1,    1,    1,    1,    2,    3,    3,    4,    4,    5,
#             ...
#             1831, 1831, 1831, 1832, 1832, 1833, 1833, 1834, 1834, 1834],
#            dtype='int64', name='order_id', length=4622)

# %% [markdown]
# # Filter the Data

# %%
df.head()
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.iloc[1:5]
# Out:
#           quantity                              item_name  \
# order_id
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
#
#                                          choice_description item_price
# order_id
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.loc[1:5]
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# 3                1                           Chicken Bowl
# 3                1                          Side of Chips
# 4                1                          Steak Burrito
# 4                1                       Steak Soft Tacos
# 5                1                          Steak Burrito
# 5                1                    Chips and Guacamole
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 3         [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 3                                                       NaN     $1.69
# 4         [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 4         [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 5         [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 5                                                       NaN     $4.45

# %%
df.loc[:,:]
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                     ...        ...
# 1833      [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 1833      [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 4 columns]

# %%
df.iloc[:,2:].head()
# Out:
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.loc[:,['item_name']].head(10)
# Out:
#                                       item_name
# order_id
# 1                  Chips and Fresh Tomato Salsa
# 1                                          Izze
# 1                              Nantucket Nectar
# 1         Chips and Tomatillo-Green Chili Salsa
# 2                                  Chicken Bowl
# 3                                  Chicken Bowl
# 3                                 Side of Chips
# 4                                 Steak Burrito
# 4                              Steak Soft Tacos
# 5                                 Steak Burrito

# %%
df.iloc[:,1:4].head(10)

# %% [markdown]
# ## Filtering using Conditions

# %%
df.loc[:,['item_name']]
# Out:
#                                       item_name
# order_id
# 1                  Chips and Fresh Tomato Salsa
# 1                                          Izze
# 1                              Nantucket Nectar
# 1         Chips and Tomatillo-Green Chili Salsa
# 2                                  Chicken Bowl
# ...                                         ...
# 1833                              Steak Burrito
# 1833                              Steak Burrito
# 1834                         Chicken Salad Bowl
# 1834                         Chicken Salad Bowl
# 1834                         Chicken Salad Bowl
#
# [4622 rows x 1 columns]

# %%
df.head()
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
#
#                                          choice_description item_price
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df[df['quantity'] > 1]['item_price'] = '$40'
# Out:
# C:\Users\Chetan\AppData\Local\Temp/ipykernel_14484/1996046055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['quantity'] > 1]['item_price'] = '$40'

# %%
df.loc[df['quantity'] > 1,'item_price'] = '$20'

# %%
df.loc[df['quantity'] > 1]
# Out:
#           quantity           item_name  \
# order_id
# 2                2        Chicken Bowl
# 9                2         Canned Soda
# 23               2         Canned Soda
# 60               2  Chicken Salad Bowl
# 67               2       Steak Burrito
# ...            ...                 ...
# 1786             4   Canned Soft Drink
# 1789             2   Canned Soft Drink
# 1812             2   Canned Soft Drink
# 1813             2  Chicken Salad Bowl
# 1822             2       Bottled Water
#
#                                          choice_description item_price
# order_id
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...        $20
# 9                                                  [Sprite]        $20
# 23                                           [Mountain Dew]        $20
# 60        [Tomatillo Green Chili Salsa, [Sour Cream, Che...        $20
# 67        [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...        $20
# ...                                                     ...        ...
# 1786                                               [Sprite]        $20
# 1789                                                 [Coke]        $20
# 1812                                                 [Coke]        $20
# 1813      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        $20
# 1822                                                    NaN        $20
#
# [267 rows x 4 columns]

# %%
df[df['quantity'] > 2].head(10)

# %%
df[(df['quantity']> 2) & (df['item_name'] == 'Canned Soft Drink')]
# df[(df['quantity']> 2) and (df['item_name'] == 'Canned Soft Drink')]
# Out:
#           quantity          item_name choice_description item_price
# order_id
# 284              3  Canned Soft Drink        [Diet Coke]     $3.75
# 350              3  Canned Soft Drink           [Sprite]     $3.75
# 379              3  Canned Soft Drink         [Lemonade]     $3.75
# 633              3  Canned Soft Drink             [Coke]     $3.75
# 1231             3  Canned Soft Drink        [Diet Coke]     $3.75
# 1247             3  Canned Soft Drink        [Diet Coke]     $3.75
# 1592             4  Canned Soft Drink             [Coke]     $5.00
# 1642             3  Canned Soft Drink        [Diet Coke]     $3.75
# 1786             4  Canned Soft Drink             [Coke]     $5.00
# 1786             4  Canned Soft Drink           [Sprite]     $5.00

# %%
df.loc[(df['quantity']> 2) & (df['item_name'] == 'Canned Soft Drink')]
# Out:
#           quantity          item_name choice_description item_price
# order_id
# 284              3  Canned Soft Drink        [Diet Coke]     $3.75
# 350              3  Canned Soft Drink           [Sprite]     $3.75
# 379              3  Canned Soft Drink         [Lemonade]     $3.75
# 633              3  Canned Soft Drink             [Coke]     $3.75
# 1231             3  Canned Soft Drink        [Diet Coke]     $3.75
# 1247             3  Canned Soft Drink        [Diet Coke]     $3.75
# 1592             4  Canned Soft Drink             [Coke]     $5.00
# 1642             3  Canned Soft Drink        [Diet Coke]     $3.75
# 1786             4  Canned Soft Drink             [Coke]     $5.00
# 1786             4  Canned Soft Drink           [Sprite]     $5.00

# %%
df.loc[df['item_name'].isin(['Bottled Water','Canned Soft Drink']),['quantity','item_price']].head(10)
# Out:
#           quantity item_price
# order_id
# 17               1     $1.09
# 38               1     $1.09
# 114              1     $1.25
# 127              1     $1.25
# 138              1     $1.09
# 139              1     $1.25
# 143              1     $1.50
# 147              1     $1.25
# 149              1     $1.25
# 149              1     $1.25

# %%
df.loc[df['item_name'].str.startswith('Veggie'),['quantity','item_price','item_name']].head(10)
# Out:
#           quantity item_price          item_name
# order_id
# 26               1    $11.25      Veggie Burrito
# 28               1    $11.25         Veggie Bowl
# 38               1     $8.49         Veggie Bowl
# 46               1     $8.49      Veggie Burrito
# 64               1    $11.25         Veggie Bowl
# 71               1    $11.25         Veggie Bowl
# 74               1     $8.49         Veggie Bowl
# 83               1    $11.25   Veggie Salad Bowl
# 86               1    $11.25         Veggie Bowl
# 93               1    $11.25         Veggie Bowl

# %% [markdown]
# # Operations on DataFrame

# %%
df.sort_values(by = 'quantity',ascending=False,inplace=True)

# %%
df
# Out:
#           quantity                     item_name  \
# order_id
# 1443            15  Chips and Fresh Tomato Salsa
# 1660            10                 Bottled Water
# 1559             8                 Side of Chips
# 1443             7                 Bottled Water
# 970              5                 Bottled Water
# ...            ...                           ...
# 1732             1             Canned Soft Drink
# 1743             1               Chicken Burrito
# 1732             1                         Chips
# 1732             1                  Chicken Bowl
# 1834             1            Chicken Salad Bowl
#
#                                          choice_description item_price  \
# order_id
# 1443                                                    NaN    $44.25
# 1660                                                    NaN    $15.00
# 1559                                                    NaN    $13.52
# 1443                                                    NaN    $10.50
# 970                                                     NaN     $7.50
# ...                                                     ...        ...
# 1732                                                 [Coke]     $1.25
# 1743      [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75
# 1732                                                    NaN     $2.15
# 1732      [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#           price_mod
# order_id
# 1443          44.25
# 1660          15.00
# 1559          13.52
# 1443          10.50
# 970            7.50
# ...             ...
# 1732           1.25
# 1743           8.75
# 1732           2.15
# 1732           8.75
# 1834           8.75
#
# [4622 rows x 5 columns]

# %%
df.sort_values(by = 'item_price',ascending = False).head(10)

# %%
def modify_item_price(row_val):
    print(f'Inside :{row_val}')

# %%
df['item_price'].apply(modify_item_price)
# Out:
# Inside :$2.39
# Inside :$3.39
# Inside :$3.39
# Inside :$2.39
# Inside :$16.98
# Inside :$10.98
# Inside :$1.69
# Inside :$11.75
# Inside :$9.25
# Inside :$9.25
# Inside :$4.45
# Inside :$8.75
# Inside :$8.75
# Inside :$11.25
# Inside :$4.45
# Inside :$2.39
# Inside :$8.49
# Inside :$8.49
# Inside :$2.18
# Inside :$8.75
# Inside :$4.45
# Inside :$8.99
# Inside :$3.39
# Inside :$10.98
# Inside :$3.39
# Inside :$2.39
# Inside :$8.49
# Inside :$8.99
# Inside :$1.09
# Inside :$8.49
# Inside :$2.39
# Inside :$8.99
# Inside :$1.69
# Inside :$8.99
# Inside :$1.09
# Inside :$8.75
# Inside :$8.75
# Inside :$4.45
# Inside :$2.95
# Inside :$11.75
# Inside :$2.15
# Inside :$4.45
# Inside :$11.25
# Inside :$11.75
# Inside :$8.75
# Inside :$10.98
# Inside :$8.99
# Inside :$3.39
# Inside :$8.99
# Inside :$3.99
# Inside :$8.99
# Inside :$2.18
# Inside :$10.98
# Inside :$1.09
# Inside :$8.99
# Inside :$2.39
# Inside :$9.25
# Inside :$11.25
# Inside :$11.75
# Inside :$2.15
# Inside :$4.45
# Inside :$9.25
# Inside :$11.25
# Inside :$8.75
# Inside :$8.99
# Inside :$8.99
# Inside :$3.39
# Inside :$8.99
# Inside :$10.98
# Inside :$8.99
# Inside :$1.69
# Inside :$8.99
# Inside :$3.99
# Inside :$8.75
# Inside :$4.45
# Inside :$8.75
# Inside :$8.75
# Inside :$2.15
# Inside :$8.75
# Inside :$11.25
# Inside :$2.15
# Inside :$9.25
# Inside :$8.75
# Inside :$8.75
# Inside :$9.25
# Inside :$8.49
# Inside :$8.99
# Inside :$1.09
# Inside :$9.25
# Inside :
# Inside :$11.25
# Inside :$11.75
# Inside :$8.75
# Inside :$17.80
# Inside :$5.00
# Inside :$5.00
# Inside :$8.75
# Inside :$2.95
# Inside :$1.25
# Inside :$11.25
# Inside :$1.25
# Inside :$2.15
# Inside :$11.25
# Inside :$2.50
# Inside :$9.25
# Inside :$1.25
# Inside :$11.25
# Inside :$2.95
# Inside :$11.75
# Inside :$2.15
# Inside :$11.25
# Inside :$1.50
# Inside :$8.99
# Inside :$1.99
# Inside :$11.49
# Inside :$8.75
# Inside :$4.45
# Inside :$1.25
# Inside :$8.75
# Inside :$4.45
# Inside :$1.25
# Inside :$1.50
# Inside :$11.75
# Inside :$8.75
# Inside :$8.75
# Inside :$11.25
# Inside :$6.49
# Inside :$11.75
# Inside :$8.75
# Inside :$2.15
# Inside :$1.25
# Inside :$6.49
# Inside :$8.75
# Inside :$4.45
# Inside :$8.75
# Inside :$4.45
# Inside :$8.75
# Inside :$11.25
# Inside :$4.45
# Inside :$6.49
# Inside :$9.25
# Inside :$8.75
# Inside :$1.25
# Inside :$4.45
# Inside :$11.25
# Inside :$8.75
# Inside :$1.50
# Inside :$8.75
# Inside :$1.50
# Inside :$1.25
# Inside :$9.25
# Inside :$9.39
# Inside :$4.45
# Inside :$9.25
# Inside :$8.75
# Inside :$4.45
# Inside :$1.25
# Inside :$11.25
# Inside :$11.75
# Inside :$8.75
# Inside :$11.25
# Inside :$9.25
# Inside :$8.75
# Inside :$11.25
# Inside :$2.50
# Inside :$17.50
# Inside :$9.25
# Inside :$4.45
# Inside :$11.25
# Inside :$1.25
# Inside :$8.75
# Inside :$4.45
# Inside :$1.50
# Inside :$8.75
# Inside :$1.50
# Inside :$1.25
# Inside :$9.39
# Inside :$8.75
# Inside :$8.75
# Inside :$4.45
# Inside :$11.25
# Inside :$1.25
# Inside :$9.25
# Inside :$4.45
# Inside :$11.25
# Inside :$8.75
# Inside :$3.00
# Inside :$8.75
# Inside :$2.15
# Inside :$1.25
# Inside :$11.25
# Inside :$11.25
# Inside :$4.45
# Inside :$11.25
# Inside :$11.25
# Inside :$8.75
# Inside :$11.75
# Inside :$11.75
# Inside :$11.75
# Inside :$8.75
# Inside :$4.45
# Inside :$1.25
# Inside :$1.50
# Inside :$8.75
# Inside :$4.45
# Inside :$1.25
# Inside :$9.25
# Inside :$9.25
# Inside :$8.75
# Inside :$4.45
# Inside :$1.25
# Inside :$11.75
# Inside :$11.25
# Inside :$1.25
# Inside :$11.75
# Inside :$11.25
# Inside :$9.25
# Inside :$2.15
# Inside :$1.50
# Inside :$8.75
# Inside :$4.45
# Inside :$11.75
# Inside :$11.75
# Inside :$11.25
# Inside :$8.75
# Inside :$8.75
# order_id
# 1       None
# 1       None
# 1       None
# 1       None
# 2       None
#         ...
# 1833    None
# 1833    None
# 1834    None
# 1834    None
# 1834    None
# Name: item_price, Length: 4622, dtype: object

# %%
def modify_col(row_item):
    print(f'Inside:{row_item}\n\n')
    price_str = row_item['item_price']
    price_str = float(price_str.strip('$'))    
    return price_str

# %%
df['price_mod'] = df.apply(modify_col,axis = 1)
# Out:
# Inside:quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 1, dtype: object
#
#
# Inside:quantity                         1
# item_name                     Izze
# choice_description    [Clementine]
# item_price                  $3.39
# Name: 1, dtype: object
#
#
# Inside:quantity                             1
# item_name             Nantucket Nectar
# choice_description             [Apple]
# item_price                      $3.39
# Name: 1, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 1, dtype: object
#
#
# Inside:quantity                                                              2
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                      $16.98
# Name: 2, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# item_price                                                      $10.98
# Name: 3, dtype: object
#
#
# Inside:quantity                          1
# item_name             Side of Chips
# choice_description              NaN
# item_price                   $1.69
# Name: 3, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# item_price                                                      $11.75
# Name: 4, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Steak Soft Tacos
# choice_description    [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# item_price                                                       $9.25
# Name: 4, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# item_price                                                       $9.25
# Name: 5, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 5, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                          Chicken Crispy Tacos
# choice_description    [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# item_price                                                       $8.75
# Name: 6, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Soft Tacos
# choice_description    [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# item_price                                                       $8.75
# Name: 6, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                      $11.25
# Name: 7, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 7, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 8, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# item_price                                                       $8.49
# Name: 8, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# item_price                                                       $8.49
# Name: 9, dtype: object
#
#
# Inside:quantity                        2
# item_name             Canned Soda
# choice_description       [Sprite]
# item_price                 $2.18
# Name: 9, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# item_price                                                       $8.75
# Name: 10, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 10, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Barbacoa Burrito
# choice_description    [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...
# item_price                                                       $8.99
# Name: 11, dtype: object
#
#
# Inside:quantity                                 1
# item_name                 Nantucket Nectar
# choice_description    [Pomegranate Cherry]
# item_price                          $3.39
# Name: 11, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# item_price                                                      $10.98
# Name: 12, dtype: object
#
#
# Inside:quantity                         1
# item_name                     Izze
# choice_description    [Grapefruit]
# item_price                  $3.39
# Name: 12, dtype: object
#
#
# Inside:quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 13, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...
# item_price                                                       $8.49
# Name: 13, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Carnitas Burrito
# choice_description    [[Tomatillo-Green Chili Salsa (Medium), Roaste...
# item_price                                                       $8.99
# Name: 14, dtype: object
#
#
# Inside:quantity                         1
# item_name              Canned Soda
# choice_description    [Dr. Pepper]
# item_price                  $1.09
# Name: 14, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# item_price                                                       $8.49
# Name: 15, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 15, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...
# item_price                                                       $8.99
# Name: 16, dtype: object
#
#
# Inside:quantity                          1
# item_name             Side of Chips
# choice_description              NaN
# item_price                   $1.69
# Name: 16, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Carnitas Bowl
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                       $8.99
# Name: 17, dtype: object
#
#
# Inside:quantity                          1
# item_name             Bottled Water
# choice_description              NaN
# item_price                   $1.09
# Name: 17, dtype: object
#
#
# Inside:quantity                                             1
# item_name                           Chicken Soft Tacos
# choice_description    [Roasted Chili Corn Salsa, Rice]
# item_price                                      $8.75
# Name: 18, dtype: object
#
#
# Inside:quantity                                                          1
# item_name                                        Chicken Soft Tacos
# choice_description    [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
# item_price                                                   $8.75
# Name: 18, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 18, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.95
# Name: 18, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Barbacoa Bowl
# choice_description    [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# item_price                                                      $11.75
# Name: 19, dtype: object
#
#
# Inside:quantity                   1
# item_name              Chips
# choice_description       NaN
# item_price            $2.15
# Name: 19, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 20, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# item_price                                                      $11.25
# Name: 20, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...
# item_price                                                      $11.75
# Name: 20, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# item_price                                                       $8.75
# Name: 20, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                      $10.98
# Name: 21, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...
# item_price                                                       $8.99
# Name: 21, dtype: object
#
#
# Inside:quantity                         1
# item_name                     Izze
# choice_description    [Blackberry]
# item_price                  $3.39
# Name: 21, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...
# item_price                                                       $8.99
# Name: 22, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $3.99
# Name: 22, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Roasted Chili Corn Salsa (Medium), [Rice, Faj...
# item_price                                                       $8.99
# Name: 23, dtype: object
#
#
# Inside:quantity                           2
# item_name                Canned Soda
# choice_description    [Mountain Dew]
# item_price                    $2.18
# Name: 23, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Roasted Chili Corn Salsa (Medium), [Black Bea...
# item_price                                                      $10.98
# Name: 24, dtype: object
#
#
# Inside:quantity                        1
# item_name             Canned Soda
# choice_description       [Sprite]
# item_price                 $1.09
# Name: 24, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                    Steak Bowl
# choice_description    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# item_price                                                       $8.99
# Name: 25, dtype: object
#
#
# Inside:quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.39
# Name: 25, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                           Barbacoa Soft Tacos
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Black...
# item_price                                                       $9.25
# Name: 26, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                Veggie Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# item_price                                                      $11.25
# Name: 26, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Barbacoa Bowl
# choice_description    [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# item_price                                                      $11.75
# Name: 27, dtype: object
#
#
# Inside:quantity                   1
# item_name              Chips
# choice_description       NaN
# item_price            $2.15
# Name: 27, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 28, dtype: object
#
#
# Inside:quantity                                         1
# item_name                         Steak Soft Tacos
# choice_description    [Fresh Tomato Salsa, Cheese]
# item_price                                  $9.25
# Name: 28, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                   Veggie Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                      $11.25
# Name: 28, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]
# item_price                                                       $8.75
# Name: 28, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                       $8.99
# Name: 29, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Steak Soft Tacos
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...
# item_price                                                       $8.99
# Name: 29, dtype: object
#
#
# Inside:quantity                         1
# item_name                     Izze
# choice_description    [Blackberry]
# item_price                  $3.39
# Name: 30, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese]]
# item_price                                                       $8.99
# Name: 30, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                      $10.98
# Name: 30, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Roasted Chili Corn Salsa (Medium), [Rice, Bla...
# item_price                                                       $8.99
# Name: 31, dtype: object
#
#
# Inside:quantity                          1
# item_name             Side of Chips
# choice_description              NaN
# item_price                   $1.69
# Name: 31, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                       $8.99
# Name: 32, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $3.99
# Name: 32, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                       $8.75
# Name: 33, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 33, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Soft Tacos
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Cheese, Sou...
# item_price                                                       $8.75
# Name: 34, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# item_price                                                       $8.75
# Name: 34, dtype: object
#
#
# Inside:quantity                   1
# item_name              Chips
# choice_description       NaN
# item_price            $2.15
# Name: 34, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# item_price                                                       $8.75
# Name: 34, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Soft Tacos
# choice_description    [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...
# item_price                                                      $11.25
# Name: 35, dtype: object
#
#
# Inside:quantity                   1
# item_name              Chips
# choice_description       NaN
# item_price            $2.15
# Name: 35, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Barbacoa Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...
# item_price                                                       $9.25
# Name: 36, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# item_price                                                       $8.75
# Name: 36, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Black Bea...
# item_price                                                       $8.75
# Name: 37, dtype: object
#
#
# Inside:quantity                                        1
# item_name                        Steak Soft Tacos
# choice_description    [Tomatillo Red Chili Salsa]
# item_price                                 $9.25
# Name: 37, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                   Veggie Bowl
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...
# item_price                                                       $8.49
# Name: 38, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                    Steak Bowl
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...
# item_price                                                       $8.99
# Name: 38, dtype: object
#
#
# Inside:quantity                          1
# item_name             Bottled Water
# choice_description              NaN
# item_price                   $1.09
# Name: 38, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Carnitas Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour ...
# item_price                                                       $9.25
# Name: 39, dtype: object
#
#
# Inside:quantity                                         1
# item_name             Chips and Fresh Tomato Salsa
# choice_description                             NaN
# item_price                                  $2.95
# Name: 39, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                    Steak Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# item_price                                                      $11.75
# Name: 40, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                    Steak Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Chees...
# item_price                                                      $11.75
# Name: 40, dtype: object
#
#
# Inside:quantity                                             1
# item_name                           Steak Crispy Tacos
# choice_description    [Fresh Tomato Salsa, Sour Cream]
# item_price                                      $9.25
# Name: 40, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Carnitas Burrito
# choice_description    [Roasted Chili Corn Salsa, [Sour Cream, Guacam...
# item_price                                                      $11.75
# Name: 41, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 41, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Barbacoa Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                       $9.25
# Name: 42, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 42, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Carnitas Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                      $11.75
# Name: 43, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                       $8.75
# Name: 43, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...
# item_price                                                       $8.75
# Name: 44, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 44, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Rice, ...
# item_price                                                       $8.99
# Name: 45, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                    Steak Bowl
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Rice, ...
# item_price                                                       $8.99
# Name: 45, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $3.99
# Name: 45, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                Veggie Burrito
# choice_description    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# item_price                                                       $8.49
# Name: 46, dtype: object
#
#
# Inside:quantity                                      1
# item_name                      Nantucket Nectar
# choice_description    [Pineapple Orange Banana]
# item_price                               $3.39
# Name: 46, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Roasted Chili Corn Salsa (Medium), [Rice, Bla...
# item_price                                                       $8.99
# Name: 47, dtype: object
#
#
# Inside:quantity                         1
# item_name              Canned Soda
# choice_description    [Dr. Pepper]
# item_price                  $1.09
# Name: 47, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# item_price                                                       $9.25
# Name: 48, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 48, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                       $8.75
# Name: 49, dtype: object
#
#
# Inside:quantity                                                1
# item_name             Chips and Tomatillo Red Chili Salsa
# choice_description                                    NaN
# item_price                                         $2.95
# Name: 49, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 49, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 50, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# item_price                                                       $8.49
# Name: 50, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Barbacoa Bowl
# choice_description    [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...
# item_price                                                       $8.99
# Name: 51, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...
# item_price                                                       $8.49
# Name: 51, dtype: object
#
#
# Inside:quantity                              1
# item_name                   Canned Soda
# choice_description    [Diet Dr. Pepper]
# item_price                       $1.09
# Name: 51, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Steak Soft Tacos
# choice_description    [[Roasted Chili Corn Salsa (Medium), Tomatillo...
# item_price                                                       $8.99
# Name: 52, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $3.99
# Name: 52, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                       $8.75
# Name: 53, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Barbacoa Burrito
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Black Bea...
# item_price                                                       $9.25
# Name: 53, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 53, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Guacamole, Cheese, Sour ...
# item_price                                                      $11.25
# Name: 54, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 54, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Roasted Chili Corn Salsa (Medium), [Rice, Bla...
# item_price                                                       $8.99
# Name: 55, dtype: object
#
#
# Inside:quantity                        1
# item_name             Canned Soda
# choice_description    [Coca Cola]
# item_price                 $1.09
# Name: 55, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Barbacoa Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Pinto Beans...
# item_price                                                       $9.25
# Name: 56, dtype: object
#
#
# Inside:quantity                                                1
# item_name             Chips and Tomatillo Red Chili Salsa
# choice_description                                    NaN
# item_price                                         $2.95
# Name: 56, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 56, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Barbacoa Burrito
# choice_description    [Roasted Chili Corn Salsa, [Rice, Pinto Beans,...
# item_price                                                      $11.75
# Name: 57, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 57, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# item_price                                                       $8.49
# Name: 58, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 58, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Roasted Chili Corn Salsa (Medium), [Rice, Bla...
# item_price                                                      $10.98
# Name: 59, dtype: object
#
#
# Inside:quantity                                                              2
# item_name                                            Chicken Salad Bowl
# choice_description    [Tomatillo Green Chili Salsa, [Sour Cream, Che...
# item_price                                                      $22.50
# Name: 60, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Barbacoa Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# item_price                                                      $11.75
# Name: 61, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 61, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...
# item_price                                                      $11.25
# Name: 62, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 62, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Sour Crea...
# item_price                                                      $11.25
# Name: 63, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 63, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                      $11.25
# Name: 64, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                   Veggie Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# item_price                                                      $11.25
# Name: 64, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Barbacoa Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Sour Cream,...
# item_price                                                      $11.75
# Name: 65, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Carnitas Bowl
# choice_description    [Roasted Chili Corn Salsa, [Rice, Fajita Veget...
# item_price                                                       $9.25
# Name: 65, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 65, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Rice, ...
# item_price                                                      $11.48
# Name: 66, dtype: object
#
#
# Inside:quantity                                                              2
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...
# item_price                                                      $17.98
# Name: 67, dtype: object
#
#
# Inside:quantity                          1
# item_name             Side of Chips
# choice_description              NaN
# item_price                   $1.69
# Name: 67, dtype: object
#
#
# Inside:quantity                                                              2
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                      $17.50
# Name: 68, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 68, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...
# item_price                                                       $8.49
# Name: 69, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 69, dtype: object
#
#
# Inside:quantity                                                              2
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                      $17.50
# Name: 70, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 70, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 71, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                   Veggie Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# item_price                                                      $11.25
# Name: 71, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Cheese, G...
# item_price                                                      $11.75
# Name: 71, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [[Roasted Chili Corn Salsa (Medium), Tomatillo...
# item_price                                                      $10.98
# Name: 72, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
# item_price                                                       $8.49
# Name: 73, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [[Roasted Chili Corn Salsa (Medium), Tomatillo...
# item_price                                                      $10.98
# Name: 73, dtype: object
#
#
# Inside:quantity                        2
# item_name             Canned Soda
# choice_description    [Diet Coke]
# item_price                 $2.18
# Name: 73, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Carnitas Bowl
# choice_description    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...
# item_price                                                      $11.48
# Name: 74, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                   Veggie Bowl
# choice_description    [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...
# item_price                                                       $8.49
# Name: 74, dtype: object
#
#
# Inside:quantity                                                  1
# item_name             Chips and Tomatillo-Green Chili Salsa
# choice_description                                      NaN
# item_price                                           $2.39
# Name: 74, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 75, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                      $11.25
# Name: 75, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                         Barbacoa Crispy Tacos
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                      $11.75
# Name: 75, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Cheese, Sou...
# item_price                                                       $8.75
# Name: 75, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomat...
# item_price                                                       $8.49
# Name: 76, dtype: object
#
#
# Inside:quantity                              2
# item_name                   Canned Soda
# choice_description    [Diet Dr. Pepper]
# item_price                       $2.18
# Name: 76, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                       $8.49
# Name: 77, dtype: object
#
#
# Inside:quantity                             1
# item_name             Nantucket Nectar
# choice_description             [Apple]
# item_price                      $3.39
# Name: 77, dtype: object
#
#
# Inside:quantity                                                            1
# item_name                                             Chicken Burrito
# choice_description    [Tomatillo-Green Chili Salsa (Medium), Lettuce]
# item_price                                                     $8.49
# Name: 78, dtype: object
#
#
# Inside:quantity                                                         1
# item_name                                         Steak Soft Tacos
# choice_description    [Roasted Chili Corn Salsa (Medium), Lettuce]
# item_price                                                  $8.99
# ...
# item_name                                                 Carnitas Bowl
# choice_description    [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# item_price                                                       $9.25
# Name: 1814, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1814, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                      $11.25
# Name: 1815, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description             [Sprite]
# item_price                       $1.25
# Name: 1815, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                               Chicken Burrito
# choice_description    [Roasted Chili Corn Salsa, [Pinto Beans, Chees...
# item_price                                                       $8.75
# Name: 1816, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1816, dtype: object
#
#
# Inside:quantity                          1
# item_name             Bottled Water
# choice_description              NaN
# item_price                   $1.50
# Name: 1817, dtype: object
#
#
# Inside:quantity                                                            1
# item_name                                             Chicken Burrito
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]
# item_price                                                     $8.75
# Name: 1817, dtype: object
#
#
# Inside:quantity                          1
# item_name             Bottled Water
# choice_description              NaN
# item_price                   $1.50
# Name: 1817, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description          [Diet Coke]
# item_price                       $1.25
# Name: 1817, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Steak Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# item_price                                                       $9.39
# Name: 1818, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                             Veggie Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# item_price                                                       $8.75
# Name: 1818, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...
# item_price                                                       $8.75
# Name: 1819, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1819, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...
# item_price                                                      $11.25
# Name: 1820, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description               [Coke]
# item_price                       $1.25
# Name: 1820, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Carnitas Burrito
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...
# item_price                                                       $9.25
# Name: 1821, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1821, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...
# item_price                                                      $11.25
# Name: 1822, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                       $8.75
# Name: 1822, dtype: object
#
#
# Inside:quantity                          2
# item_name             Bottled Water
# choice_description              NaN
# item_price                   $3.00
# Name: 1822, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Black Bea...
# item_price                                                       $8.75
# Name: 1823, dtype: object
#
#
# Inside:quantity                   1
# item_name              Chips
# choice_description       NaN
# item_price            $2.15
# Name: 1823, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description          [Diet Coke]
# item_price                       $1.25
# Name: 1823, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# item_price                                                      $11.25
# Name: 1824, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# item_price                                                      $11.25
# Name: 1824, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1824, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# item_price                                                      $11.25
# Name: 1825, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# item_price                                                      $11.25
# Name: 1825, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# item_price                                                       $8.75
# Name: 1825, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                              Barbacoa Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...
# item_price                                                      $11.75
# Name: 1825, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Carnitas Bowl
# choice_description    [Roasted Chili Corn Salsa, [Rice, Sour Cream, ...
# item_price                                                      $11.75
# Name: 1825, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Barbacoa Bowl
# choice_description    [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...
# item_price                                                      $11.75
# Name: 1825, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Black Bea...
# item_price                                                       $8.75
# Name: 1826, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1826, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description             [Nestea]
# item_price                       $1.25
# Name: 1826, dtype: object
#
#
# Inside:quantity                          1
# item_name             Bottled Water
# choice_description              NaN
# item_price                   $1.50
# Name: 1826, dtype: object
#
#
# Inside:quantity                                                          1
# item_name                                              Chicken Bowl
# choice_description    [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
# item_price                                                   $8.75
# Name: 1827, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1827, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description          [Diet Coke]
# item_price                       $1.25
# Name: 1827, dtype: object
#
#
# Inside:quantity                                          1
# item_name                          Barbacoa Burrito
# choice_description    [Tomatillo Green Chili Salsa]
# item_price                                   $9.25
# Name: 1827, dtype: object
#
#
# Inside:quantity                                          1
# item_name                          Barbacoa Burrito
# choice_description    [Tomatillo Green Chili Salsa]
# item_price                                   $9.25
# Name: 1827, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                  Chicken Bowl
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
# item_price                                                       $8.75
# Name: 1828, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1828, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description               [Coke]
# item_price                       $1.25
# Name: 1828, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# item_price                                                      $11.75
# Name: 1829, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                Veggie Burrito
# choice_description    [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# item_price                                                      $11.25
# Name: 1829, dtype: object
#
#
# Inside:quantity                              1
# item_name             Canned Soft Drink
# choice_description             [Sprite]
# item_price                       $1.25
# Name: 1829, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# item_price                                                      $11.75
# Name: 1830, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                Veggie Burrito
# choice_description    [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
# item_price                                                      $11.25
# Name: 1830, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Carnitas Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                       $9.25
# Name: 1831, dtype: object
#
#
# Inside:quantity                   1
# item_name              Chips
# choice_description       NaN
# item_price            $2.15
# Name: 1831, dtype: object
#
#
# Inside:quantity                          1
# item_name             Bottled Water
# choice_description              NaN
# item_price                   $1.50
# Name: 1831, dtype: object
#
#
# Inside:quantity                                                             1
# item_name                                           Chicken Soft Tacos
# choice_description    [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]
# item_price                                                      $8.75
# Name: 1832, dtype: object
#
#
# Inside:quantity                                1
# item_name             Chips and Guacamole
# choice_description                    NaN
# item_price                         $4.45
# Name: 1832, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# item_price                                                      $11.75
# Name: 1833, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# item_price                                                      $11.75
# Name: 1833, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# item_price                                                      $11.25
# Name: 1834, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# item_price                                                       $8.75
# Name: 1834, dtype: object
#
#
# Inside:quantity                                                              1
# item_name                                            Chicken Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# item_price                                                       $8.75
# Name: 1834, dtype: object

# %%
df
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description item_price  \
# order_id
# 1                                                       NaN     $2.39
# 1                                              [Clementine]     $3.39
# 1                                                   [Apple]     $3.39
# 1                                                       NaN     $2.39
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                     ...        ...
# 1833      [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 1833      [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 1834      [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#           price_mod
# order_id
# 1              2.39
# 1              3.39
# 1              3.39
# 1              2.39
# 2             16.98
# ...             ...
# 1833          11.75
# 1833          11.75
# 1834          11.25
# 1834           8.75
# 1834           8.75
#
# [4622 rows x 5 columns]

# %%
df.apply(modify_col,axis = 0)
# Out:
# Inside:order_id
# 1       1
# 1       1
# 1       1
# 1       1
# 2       2
#        ..
# 1833    1
# 1833    1
# 1834    1
# 1834    1
# 1834    1
# Name: quantity, Length: 4622, dtype: int64
# Inside:order_id
# 1                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 1                            Nantucket Nectar
# 1       Chips and Tomatillo-Green Chili Salsa
# 2                                Chicken Bowl
#                         ...
# 1833                            Steak Burrito
# 1833                            Steak Burrito
# 1834                       Chicken Salad Bowl
# 1834                       Chicken Salad Bowl
# 1834                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object
# Inside:order_id
# 1                                                     NaN
# 1                                            [Clementine]
# 1                                                 [Apple]
# 1                                                     NaN
# 2       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 1833    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 1833    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 1834    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 1834    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 1834    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object
# Inside:order_id
# 1        $2.39
# 1        $3.39
# 1        $3.39
# 1        $2.39
# 2       $16.98
#          ...
# 1833    $11.75
# 1833    $11.75
# 1834    $11.25
# 1834     $8.75
# 1834     $8.75
# Name: item_price, Length: 4622, dtype: object
# quantity              None
# item_name             None
# choice_description    None
# item_price            None
# dtype: object

# %%
item_price_mod = df['item_price'].apply(lambda x : float(x.strip('$')))
item_price_mod
df['item_price_mod'] = item_price_mod
df.head()

# %%
df['gst_price'] = df['item_price_mod'] * 0.18 + df['item_price_mod']
df.head(10)

# %%
df['revenue'] = df['item_price_mod']*df['quantity']
df.head()

# %% [markdown]
# # INDEXES

# %%
# Using the books dataframe for this section
df = df_books
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors average_rating        isbn       isbn13  \
# 0  J.K. Rowling-Mary GrandPré           4.56   439785960  9.78044E+12
# 1  J.K. Rowling-Mary GrandPré           4.49   439358078  9.78044E+12
# 2  J.K. Rowling-Mary GrandPré           4.47   439554934  9.78044E+12
# 3                J.K. Rowling           4.41   439554896  9.78044E+12
# 4  J.K. Rowling-Mary GrandPré           4.55  043965548X  9.78044E+12
#
#   language_code # num_pages  ratings_count  text_reviews_count  Unnamed: 10
# 0           eng         652        1944099               26249          NaN
# 1           eng         870        1996446               27613          NaN
# 2           eng         320        5629932               70390          NaN
# 3           eng         352           6267                 272          NaN
# 4           eng         435        2149872               33964          NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13718, step=1)

# %%
df.tail(10)
# Out:
#        bookID                                              title  \
# 13708   47687  Peace Pact: The Lost World of the American Fou...
# 13709   47692                                      American Gods
# 13710   47693          The Day I Swapped My Dad for Two Goldfish
# 13711   47695                                Harlequin Valentine
# 13712   47697                        The Sandman: King of Dreams
# 13713   47699                                     M Is for Magic
# 13714   47700                                       Black Orchid
# 13715   47701                        InterWorld (InterWorld  #1)
# 13716   47708                                The Faeries' Oracle
# 13717   47709                      The World of The Dark Crystal
#
#                              authors average_rating        isbn       isbn13  \
# 13708           David C. Hendrickson            3.3   700614931   9.7807E+12
# 13709                    Neil Gaiman           4.11  1594970998  9.78159E+12
# 13710        Neil Gaiman-Dave McKean           4.03    60587016  9.78006E+12
# 13711        Neil Gaiman-John Bolton           3.79  1840234113  9.78184E+12
# 13712      Alisa Kwitney-Neil Gaiman           4.62   811835928  9.78081E+12
# 13713  Neil Gaiman-Teddy Kristiansen           3.82    61186422  9.78006E+12
# 13714        Neil Gaiman-Dave McKean           3.72   930289552  9.78093E+12
# 13715     Neil Gaiman-Michael Reaves           3.53    61238961  9.78006E+12
# 13716    Brian Froud-Jessica Macbeth           4.43   743201116  9.78074E+12
# 13717                    Brian Froud           4.29  1862056242  9.78186E+12
#
#       language_code # num_pages  ratings_count  text_reviews_count  \
# 13708           eng         402             21                   0
# 13709           spa         477             58                   6
# 13710         en-US          64           8744                 524
# 13711           eng          40           2441                  68
# 13712           eng         180          12775                  34
# 13713           eng         260          11317                1060
# 13714           eng         160           8710                 361
# 13715         en-US         239          14334                1485
# 13716           eng         224           1550                  38
# 13717           eng         132           3572                  33
#
#        Unnamed: 10
# 13708          NaN
# 13709          NaN
# 13710          NaN
# 13711          NaN
# 13712          NaN
# 13713          NaN
# 13714          NaN
# 13715          NaN
# 13716          NaN
# 13717          NaN

# %%
# %%time 
df[df['authors'] =='David C. Hendrickson']
# Out:
# Wall time: 3.99 ms
#        bookID                                              title  \
# 13708   47687  Peace Pact: The Lost World of the American Fou...
#
#                     authors average_rating       isbn      isbn13  \
# 13708  David C. Hendrickson            3.3  700614931  9.7807E+12
#
#       language_code # num_pages  ratings_count  text_reviews_count  \
# 13708           eng         402             21                   0
#
#        Unnamed: 10
# 13708          NaN

# %%
s = df.set_index('authors').sort_index()

# %%
s.head(5)
# Out:
#                                                     bookID  \
# authors
# A.B. Yehoshua-Hillel Halkin                          30855
# A.B. Yehoshua-Hillel Halkin                          27503
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky         17883
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...   40880
# A.J. Jacobs                                          28116
#
#                                                                                                 title  \
# authors
# A.B. Yehoshua-Hillel Halkin                                                      A Woman in Jerusalem
# A.B. Yehoshua-Hillel Halkin                                                       The Liberated Bride
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky        Notes from Underground & A Confession (Everyma...
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...  Jack Vance: Critical Appreciations and a Bibli...
# A.J. Jacobs                                         The Know-It-All: One Man's Humble Quest to Bec...
#
#                                                    average_rating       isbn  \
# authors
# A.B. Yehoshua-Hillel Halkin                                  3.41  151012261
# A.B. Yehoshua-Hillel Halkin                                  3.76  156030160
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky                 3.76  460874489
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...           4.15  712311025
# A.J. Jacobs                                                  3.77  743250621
#
#                                                          isbn13 language_code  \
# authors
# A.B. Yehoshua-Hillel Halkin                         9.78015E+12         en-US
# A.B. Yehoshua-Hillel Halkin                         9.78016E+12         en-US
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky        9.78046E+12           eng
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...  9.78071E+12           eng
# A.J. Jacobs                                         9.78074E+12           eng
#
#                                                    # num_pages  ratings_count  \
# authors
# A.B. Yehoshua-Hillel Halkin                                256            820
# A.B. Yehoshua-Hillel Halkin                                576            449
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky               256             17
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...         232             13
# A.J. Jacobs                                                389          23343
#
#                                                     text_reviews_count  \
# authors
# A.B. Yehoshua-Hillel Halkin                                        128
# A.B. Yehoshua-Hillel Halkin                                         43
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky                         1
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...                   2
# A.J. Jacobs                                                       2312
#
#                                                     Unnamed: 10
# authors
# A.B. Yehoshua-Hillel Halkin                                 NaN
# A.B. Yehoshua-Hillel Halkin                                 NaN
# A.D.P. Briggs-Leo Tolstoy-Fyodor Dostoyevsky                NaN
# A.E. Cunningham-Harlan Ellison-Charles F. Mille...          NaN
# A.J. Jacobs                                                 NaN

# %%
# %%time
s.loc['David C. Hendrickson']
# s.loc['David C. Hendrickson']
# Out:
# Wall time: 998 µs
# bookID                                                            47687
# title                 Peace Pact: The Lost World of the American Fou...
# average_rating                                                      3.3
# isbn                                                          700614931
# isbn13                                                       9.7807E+12
# language_code                                                       eng
# # num_pages                                                         402
# ratings_count                                                        21
# text_reviews_count                                                    0
# Unnamed: 10                                                         NaN
# Name: David C. Hendrickson, dtype: object

# %%
df.head()

p_i = df.set_index(['authors','title']).sort_index()
p_i

# %% [markdown]
# # GroupBy

# %%
# use df_cricket dataset
df = df_cricket
df.head()
# Out:
#        id  season    city        date                        team1  \
# 0  419164    2010  Mumbai  2010-04-24  Royal Challengers Bangalore
# 1  419131    2010   Delhi  2010-03-29             Delhi Daredevils
# 2  336021    2008  Mumbai  2008-05-16               Mumbai Indians
# 3  980931    2016    Pune  2016-04-22      Rising Pune Supergiants
# 4  419163    2010  Mumbai  2010-04-22          Chennai Super Kings
#
#                          team2              toss_winner toss_decision  \
# 0              Deccan Chargers          Deccan Chargers           bat
# 1        Kolkata Knight Riders         Delhi Daredevils           bat
# 2        Kolkata Knight Riders           Mumbai Indians         field
# 3  Royal Challengers Bangalore  Rising Pune Supergiants         field
# 4              Deccan Chargers      Chennai Super Kings           bat
#
#                         winner eliminator  ... overs  player_of_match  \
# 0  Royal Challengers Bangalore        NaN  ...    20         A Kumble
# 1             Delhi Daredevils        NaN  ...    20        DA Warner
# 2               Mumbai Indians        NaN  ...    20       SM Pollock
# 3  Royal Challengers Bangalore        NaN  ...    20   AB de Villiers
# 4          Chennai Super Kings        NaN  ...    20     DE Bollinger
#
#                                      venue      umpire1     umpire2 umpire3  \
# 0               Dr DY Patil Sports Academy  RE Koertzen  SJA Taufel     NaN
# 1                         Feroz Shah Kotla    SS Hazare  SJA Taufel     NaN
# 2                         Wankhede Stadium  BR Doctrove   DJ Harper     NaN
# 3  Maharashtra Cricket Association Stadium  CB Gaffaney   VK Sharma     NaN
# 4               Dr DY Patil Sports Academy  BR Doctrove   RB Tiffin     NaN
#
#                 first_bat_team              first_bowl_team first_bat_score  \
# 0              Deccan Chargers  Royal Challengers Bangalore            82.0
# 1             Delhi Daredevils        Kolkata Knight Riders           177.0
# 2        Kolkata Knight Riders               Mumbai Indians            67.0
# 3  Royal Challengers Bangalore      Rising Pune Supergiants           185.0
# 4          Chennai Super Kings              Deccan Chargers           142.0
#
#   second_bat_score
# 0             86.0
# 1            137.0
# 2             68.0
# 3            172.0
# 4            104.0
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'eliminator', 'dl_applied', 'win_by_runs',
#        'win_by_wickets', 'result', 'overs', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3', 'first_bat_team', 'first_bowl_team',
#        'first_bat_score', 'second_bat_score'],
#       dtype='object')

# %%
df['venue'].unique()
# Out:
# array(['Dr DY Patil Sports Academy', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Maharashtra Cricket Association Stadium',
#        'Punjab Cricket Association Stadium, Mohali',
#        'M Chinnaswamy Stadium', 'Eden Gardens',
#        'MA Chidambaram Stadium, Chepauk',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'Sawai Mansingh Stadium',
#        'Himachal Pradesh Cricket Association Stadium',
#        'Saurashtra Cricket Association Stadium', 'Green Park',
#        'New Wanderers Stadium',
#        'Punjab Cricket Association IS Bindra Stadium, Mohali',
#        'Holkar Cricket Stadium', 'Subrata Roy Sahara Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Dubai International Cricket Stadium', 'Kingsmead',
#        'Nehru Stadium', 'JSCA International Stadium Complex',
#        'Sardar Patel Stadium, Motera', 'Sharjah Cricket Stadium',
#        'Brabourne Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'Sheikh Zayed Stadium', 'M.Chinnaswamy Stadium',
#        "St George's Park", 'Newlands', 'SuperSport Park', 'Buffalo Park',
#        'Barabati Stadium', 'OUTsurance Oval', 'De Beers Diamond Oval'],
#       dtype=object)

# %% [markdown]
# ## Analyze for each season ,how were the most of the matches won, on basis of batting strength or bowling strength

# %%
df['won_by'] = df['win_by_runs'].fillna(0)
df['won_by'] = df['won_by'].apply(lambda x: 'field' if x == 0 else 'bat')

# %%
wb = df.groupby(by = ['season','won_by'])['winner'].count()
wb
# Out:
# season  won_by
# 2008    bat       24
#         field     34
# 2009    bat       27
#         field     29
# 2010    bat       31
#         field     28
# 2011    bat       33
#         field     39
# 2012    bat       34
#         field     40
# 2013    bat       37
#         field     37
# 2014    bat       22
#         field     37
# 2015    bat       32
#         field     24
# 2016    bat       21
#         field     39
# 2017    bat       26
#         field     32
# 2018    bat       28
#         field     32
# 2019    bat       21
#         field     27
# Name: winner, dtype: int64

# %%
wb.unstack(1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='season'>

# %% [markdown]
# ## How many won the toss as well as the match

# %%
toss_team = df[df['toss_winner']==df['winner']]
td = toss_team.groupby(by = ['season','toss_decision'])['winner'].count()
td

td.unstack(1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='season'>

# %% [markdown]
# ## Analyze for a particular venue and team

# %%
rcb_win = df[df['winner']=='Royal Challengers Bangalore']
rcb_t = rcb_win.groupby(by = ['season','won_by','venue'])['winner'].count()
rcb_home = rcb_t.unstack(2)#.plot(kind = 'bar')
rcb_home.loc[:,'M Chinnaswamy Stadium'].unstack(1).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='season'>

# %% [markdown]
# ## Analyse the venue

# %%
venue = df[df['venue']=='Eden Gardens']
venue_g = venue.groupby(by = ['season','won_by'])['winner'].count()
venue_g.unstack(1).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='season'>

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Univariant scatter plot

# %%
tips = df_tips
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = plt.figure()
axes_tips = fig.add_subplot(1,1,1)
# tips.hist(column='total_bill',bins=10,ax=axes_tips)
axes_tips.hist(tips['total_bill'], bins=10)
axes_tips.set_title('Histogram of Total Bill')
axes_tips.set_xlabel('Total Bill')
axes_tips.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Bivariant Statistical Plot

# %%
scatter_plot = plt.figure()
axes_bi = scatter_plot.add_subplot(1,1,1)
# tips.plot(x='total_bill',y='tip',kind = 'scatter',ax=axes_bi,s = tips['size']*10)
axes_bi.scatter(tips['total_bill'],tips['tip'])
axes_bi.set_xlabel('Total Bill')
axes_bi.set_ylabel('Tips')
axes_bi.set_title('Scatterplot of Total Bill vs Tip')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Total Bill vs Tip')

# %% [markdown]
# ## Box Plot

# %%
boxplot = plt.figure()
axes_box = boxplot.add_subplot(1,1,1)
# axes_box.boxplot([tips[tips['sex'] =='Female']['tip'],tips[tips['sex']=='Male']['tip']],labels=['Female','Male'])
tips.boxplot(column='total_bill',by='sex',ax=axes_box)
boxplot.add_axes(axes_box)
axes_box.set_xlabel('Sex')
axes_box.set_ylabel('Tip')
axes_box.set_title('Boxplot of Tips by Sex')
boxplot.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %%
tips.groupby(by=['sex']).mean()\
.plot.pie(y = 'total_bill')
# Out:
# <AxesSubplot:ylabel='total_bill'>
